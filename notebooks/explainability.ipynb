# %%
import pickle
import pandas as pd
import numpy as np
from pathlib import Path

model_dir = Path("D:/customer_churn_ml/model")

with open(model_dir / "churn_model.pkl", "rb") as f:
    model = pickle.load(f)

with open(model_dir / "encoders.pkl", "rb") as f:
    encoders = pickle.load(f)

with open(model_dir / "scaler.pkl", "rb") as f:
    scaler = pickle.load(f)
